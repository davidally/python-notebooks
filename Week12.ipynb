# %% [markdown]
# # Week 12 - Predictive Analytics

# %%
import pandas as pd
import json
import sys

# %%
URL="https://api.nytimes.com/svc/mostpopular/v2/shared/1.json?api-key=iw3ZZcJGYkBF3TXHTEisj7WUyC7kvoQ6"
df = pd.read_json(URL)
df = pd.DataFrame(df['results'].values.tolist())[0:10]

# %% [markdown]
# ## New York Times Most Popular Shared Articles (API)

# %%
#Shift title of article to first column
df = df[['title'] + [col for col in df.columns if col != 'title']]
df
# Out:
#                                                title  \
# 0  Top Health Officials to Quarantine After Being...
# 1  Jerry Stiller, Comedian With Enduring Appeal, ...
# 2              McDonald’s Workers in Denmark Pity Us
# 3                                  How Pandemics End
# 4  Bill Barr Twisted My Words in Dropping the Fly...
# 5                 This Is the Future of the Pandemic
# 6  Mysterious Coronavirus Illness Claims 3 Childr...
# 7  10-4: How to Reopen the Economy by Exploiting ...
# 8  How the ‘Outlander’ Team Managed That Shocking...
# 9                     The World Is Taking Pity on Us
#
#                                                  uri  \
# 0  nyt://article/dcbac4db-533e-5832-8de9-01a27c13...
# 1  nyt://article/11f1a91d-7e8f-59bc-80b1-370e2cd4...
# 2  nyt://article/b6fd0b5d-d290-52f6-ad72-2b7b3743...
# 3  nyt://article/f3c5d1ae-c062-5a27-9e8c-e0109c5a...
# 4  nyt://article/fa009707-5a9c-5ac6-8836-173b909a...
# 5  nyt://article/38ca73d1-2b80-5c25-afc3-94ff4e34...
# ...
