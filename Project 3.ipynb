# %% [markdown]
# # Project 3 - Working with Structured Data

# %%
import pandas as pd
import sqlite3

# %%
file= r'C:\Users\DMichael\Desktop\Chinook_Sqlite.sqlite'
connection = sqlite3.connect(file)
data = pd.read_sql("SELECT * FROM project_query ", connection)
df =  pd.DataFrame(data)
df
# Out:
#         LastName FirstName                                               Name  \
# 0         Köhler    Leonie                                  Balls to the Wall
# 1         Köhler    Leonie                                  Restless and Wild
# 2         Hansen     Bjørn                              Put The Finger On You
# 3         Hansen     Bjørn                                   Inject The Venom
# 4         Hansen     Bjørn                                         Evil Walks
# ...          ...       ...                                                ...
# 2235  Hämäläinen     Terhi                                   Looking For Love
# 2236  Hämäläinen     Terhi                                    Sweet Lady Luck
# 2237  Hämäläinen     Terhi  Feirinha da Pavuna/Luz do Repente/Bagaço da La...
# 2238  Hämäläinen     Terhi                                   Samba pras moças
# 2239      Pareek     Manoj                                           Hot Girl
#
# ...
