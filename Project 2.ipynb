# %% [markdown]
# # Project 2

# %%
import pandas as pd
import numpy as np
import sys

# %%
URL1="https://raw.githubusercontent.com/davidally/python-notebooks/master/cars.csv"
URL2="https://raw.githubusercontent.com/davidally/python-notebooks/master/cereal.csv"
URL3="https://raw.githubusercontent.com/davidally/python-notebooks/master/factbook.csv"

# %% [markdown]
# ## Tidy Cars.csv

# %%
#Organize data into proper columns
df = pd.read_csv(URL1, sep=";")
df.apply(pd.to_numeric, errors='coerce')
df
# Out:
#                                       Car     MPG Cylinders Displacement  \
# 0                                  STRING  DOUBLE       INT       DOUBLE
# 1               Chevrolet Chevelle Malibu    18.0         8        307.0
# 2                       Buick Skylark 320    15.0         8        350.0
# 3                      Plymouth Satellite    18.0         8        318.0
# 4                           AMC Rebel SST    16.0         8        304.0
# 5                             Ford Torino    17.0         8        302.0
# 6                        Ford Galaxie 500    15.0         8        429.0
# 7                        Chevrolet Impala    14.0         8        454.0
# 8                       Plymouth Fury iii    14.0         8        440.0
# 9                        Pontiac Catalina    14.0         8        455.0
# 10                     AMC Ambassador DPL    15.0         8        390.0
# 11                   Citroen DS-21 Pallas       0         4        133.0
# ...

# %% [markdown]
# ## Tidy Cereal.csv

# %%
#Organize data into proper columns and clear bad rows
df_two = pd.read_csv(URL2, error_bad_lines=False, sep=";")
df_two
# Out:
#                                       name          mfr         type calories  \
# 0                                   String  Categorical  Categorical      Int
# 1                                100% Bran            N            C       70
# 2                        100% Natural Bran            Q            C      120
# 3                                 All-Bran            K            C       70
# 4                All-Bran with Extra Fiber            K            C       50
# 5                           Almond Delight            R            C      110
# 6                  Apple Cinnamon Cheerios            G            C      110
# 7                              Apple Jacks            K            C      110
# 8                                  Basic 4            G            C      130
# 9                                Bran Chex            R            C       90
# 10                             Bran Flakes            P            C       90
# ...

# %% [markdown]
# ## Tidy Factbook.csv

# %%
#Organize data into proper columns and clear bad rows
df_three = pd.read_csv(URL3, sep=";")
df_three.apply(pd.to_numeric, errors='coerce')
df_three
# Out:
#                                           Country Area(sq km)  \
# 0                                          String      double
# 1                                     Afghanistan      647500
# 2                                        Akrotiri         123
# 3                                         Albania       28748
# 4                                         Algeria     2381740
# 5                                  American Samoa         199
# 6                                         Andorra         468
# 7                                          Angola     1246700
# 8                                        Anguilla         102
# 9                                      Antarctica    14000000
# 10                            Antigua and Barbuda         443
# 11                                      Argentina     2766890
# 12                                        Armenia       29800
# 13                                          Aruba         193
# ...

# %%
#Check missing values
df_three.isnull().sum().sum()
# Out:
# 3656

# %% [markdown]
# ## Replace missing values with numerical values

# %%
df_three.fillna(0, inplace=True)
df_three
# Out:
#                                           Country Area(sq km)  \
# 0                                          String      double
# 1                                     Afghanistan      647500
# 2                                        Akrotiri         123
# 3                                         Albania       28748
# 4                                         Algeria     2381740
# 5                                  American Samoa         199
# 6                                         Andorra         468
# 7                                          Angola     1246700
# 8                                        Anguilla         102
# 9                                      Antarctica    14000000
# 10                            Antigua and Barbuda         443
# 11                                      Argentina     2766890
# 12                                        Armenia       29800
# 13                                          Aruba         193
# ...

# %% [markdown]
# ### Data is now uniform type and missing values are taken care of.
