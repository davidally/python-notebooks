# %% [markdown]
# # Week 8 - Exploratory Data Analysis

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
import sys

# %%
file= r'C:\Users\DMichael\Desktop\auto-mpg.data'
#Separate by white space
data = pd.read_csv(file, header=None, delimiter=r"\s+")
#Join files into DataFrame
df = pd.DataFrame(data.values, columns=['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model Year',
                                'Origin', 'Car Name'])
df
# Out:
#     MPG Cylinders Displacement Horsepower Weight Acceleration Model Year  \
# 0    18         8          307      130.0   3504           12         70
# 1    15         8          350      165.0   3693         11.5         70
# 2    18         8          318      150.0   3436           11         70
# 3    16         8          304      150.0   3433           12         70
# 4    17         8          302      140.0   3449         10.5         70
# ..   ..       ...          ...        ...    ...          ...        ...
# 393  27         4          140      86.00   2790         15.6         82
# 394  44         4           97      52.00   2130         24.6         82
# 395  32         4          135      84.00   2295         11.6         82
# 396  28         4          120      79.00   2625         18.6         82
# 397  31         4          119      82.00   2720         19.4         82
#
#     Origin                   Car Name
# 0        1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Fixing the data

# %%
#Deal with missing values
df = df[~df['Horsepower'].isin(['?'])]
#Convert Horsepower to numeric type
pd.to_numeric(df['Horsepower'], errors="coerce")
#Convert origin values to geographic areas
df['Origin'].replace([1,2,3],['USA','Asia', 'Europe'],inplace=True)
df
# Out:
#     MPG Cylinders Displacement Horsepower Weight Acceleration Model Year  \
# 0    18         8          307      130.0   3504           12         70
# 1    15         8          350      165.0   3693         11.5         70
# 2    18         8          318      150.0   3436           11         70
# 3    16         8          304      150.0   3433           12         70
# 4    17         8          302      140.0   3449         10.5         70
# ..   ..       ...          ...        ...    ...          ...        ...
# 393  27         4          140      86.00   2790         15.6         82
# 394  44         4           97      52.00   2130         24.6         82
# 395  32         4          135      84.00   2295         11.6         82
# 396  28         4          120      79.00   2625         18.6         82
# 397  31         4          119      82.00   2720         19.4         82
#
#     Origin                   Car Name
# 0      USA  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Cylinder Distribution

# %%
df.plot.bar(x='Cylinders')

# %% [markdown]
# ## Horsepower vs. Weight

# %%
plt.scatter(x=df['Horsepower'], y=df['Weight'])
plt.show()

# %% [markdown]
# ## Question
#
# ### Has mileage improved with time (MPG vs Model Year)?

# %%
sb.barplot(data=df, x="Model Year", y="MPG")
plt.show()
